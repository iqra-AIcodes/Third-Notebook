# %%
secret = 7
guess = int(input("Enter your guess:"))
if guess == secret :
    print("Hurray!you got it, Congratulations.")
elif guess > secret :
    print("No,too high.")
else :
    print("No,too low.")
# Out:
# Enter your guess: 5
# No,too low.

# %%
secret = 7
guess = int(input("Enter your guess:"))
if guess == secret :
    print("Hurray!you got it, Congratulations.")
elif guess > secret :
    print("No,too high.")
else :
    print("No,too low.")
# Out:
# Enter your guess: 9
# No,too high.

# %%
secret = 7
guess = int(input("Enter your guess:"))
if guess == secret :
    print("Hurray!you got it, Congratulations.")
elif guess > secret :
    print("No,too high.")
else :
    print("No,too low.")
# Out:
# Enter your guess: 7
# Hurray!you got it, Congratulations.
